# %% [markdown]
# Import Libraries....

# %%
 import pandas as pd
 import numpy as np
 import matplotlib.pyplot as plt
 import seaborn as sns
 import matplotlib.pyplot as plt

# %% [markdown]
# Load Data.....

# %%
df = pd.read_csv('/content/ncr_ride_bookings.csv')
display(df.head())
# Out:
#          Date      Time    Booking ID   Booking Status   Customer ID  \
# 0  2024-03-23  12:29:38  "CNR5884300"  No Driver Found  "CID1982111"
# 1  2024-11-29  18:01:39  "CNR1326809"       Incomplete  "CID4604802"
# 2  2024-08-23  08:56:10  "CNR8494506"        Completed  "CID9202816"
# 3  2024-10-21  17:17:25  "CNR8906825"        Completed  "CID2610914"
# 4  2024-09-16  22:08:00  "CNR1950162"        Completed  "CID9933542"
#
#     Vehicle Type      Pickup Location      Drop Location  Avg VTAT  Avg CTAT  \
# 0          eBike          Palam Vihar            Jhilmil       NaN       NaN
# 1       Go Sedan        Shastri Nagar  Gurgaon Sector 56       4.9      14.0
# 2           Auto              Khandsa      Malviya Nagar      13.4      25.8
# 3  Premier Sedan  Central Secretariat           Inderlok      13.1      28.5
# 4           Bike     Ghitorni Village        Khan Market       5.3      19.6
#
#    ...  Reason for cancelling by Customer Cancelled Rides by Driver  \
# 0  ...                                NaN                       NaN
# 1  ...                                NaN                       NaN
# 2  ...                                NaN                       NaN
# 3  ...                                NaN                       NaN
# 4  ...                                NaN                       NaN
#
#    Driver Cancellation Reason Incomplete Rides  Incomplete Rides Reason  \
# 0                         NaN              NaN                      NaN
# 1                         NaN              1.0        Vehicle Breakdown
# 2                         NaN              NaN                      NaN
# 3                         NaN              NaN                      NaN
# 4                         NaN              NaN                      NaN
#
#   Booking Value  Ride Distance  Driver Ratings  Customer Rating  \
# 0           NaN            NaN             NaN              NaN
# 1         237.0           5.73             NaN              NaN
# 2         627.0          13.58             4.9              4.9
# 3         416.0          34.02             4.6              5.0
# 4         737.0          48.21             4.1              4.3
#
#    Payment Method
# 0             NaN
# 1             UPI
# 2      Debit Card
# 3             UPI
# 4             UPI
#
# [5 rows x 21 columns]

# %% [markdown]
# Basic Info.....

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Date                               150000 non-null  object
#  1   Time                               150000 non-null  object
#  2   Booking ID                         150000 non-null  object
#  3   Booking Status                     150000 non-null  object
#  4   Customer ID                        150000 non-null  object
#  5   Vehicle Type                       150000 non-null  object
#  6   Pickup Location                    150000 non-null  object
#  7   Drop Location                      150000 non-null  object
#  8   Avg VTAT                           139500 non-null  float64
#  9   Avg CTAT                           102000 non-null  float64
#  10  Cancelled Rides by Customer        10500 non-null   float64
#  11  Reason for cancelling by Customer  10500 non-null   object
#  12  Cancelled Rides by Driver          27000 non-null   float64
#  13  Driver Cancellation Reason         27000 non-null   object
#  14  Incomplete Rides                   9000 non-null    float64
#  15  Incomplete Rides Reason            9000 non-null    object
#  16  Booking Value                      102000 non-null  float64
#  17  Ride Distance                      102000 non-null  float64
#  18  Driver Ratings                     93000 non-null   float64
#  19  Customer Rating                    93000 non-null   float64
#  20  Payment Method                     102000 non-null  object
# dtypes: float64(9), object(12)
# memory usage: 24.0+ MB
# None

# %%
print(df.head())
# Out:
#          Date      Time    Booking ID   Booking Status   Customer ID  \
# 0  2024-03-23  12:29:38  "CNR5884300"  No Driver Found  "CID1982111"
# 1  2024-11-29  18:01:39  "CNR1326809"       Incomplete  "CID4604802"
# 2  2024-08-23  08:56:10  "CNR8494506"        Completed  "CID9202816"
# 3  2024-10-21  17:17:25  "CNR8906825"        Completed  "CID2610914"
# 4  2024-09-16  22:08:00  "CNR1950162"        Completed  "CID9933542"
#
#     Vehicle Type      Pickup Location      Drop Location  Avg VTAT  Avg CTAT  \
# 0          eBike          Palam Vihar            Jhilmil       NaN       NaN
# 1       Go Sedan        Shastri Nagar  Gurgaon Sector 56       4.9      14.0
# 2           Auto              Khandsa      Malviya Nagar      13.4      25.8
# 3  Premier Sedan  Central Secretariat           Inderlok      13.1      28.5
# 4           Bike     Ghitorni Village        Khan Market       5.3      19.6
#
#    ...  Reason for cancelling by Customer Cancelled Rides by Driver  \
# 0  ...                                NaN                       NaN
# 1  ...                                NaN                       NaN
# 2  ...                                NaN                       NaN
# 3  ...                                NaN                       NaN
# 4  ...                                NaN                       NaN
#
#    Driver Cancellation Reason Incomplete Rides  Incomplete Rides Reason  \
# 0                         NaN              NaN                      NaN
# 1                         NaN              1.0        Vehicle Breakdown
# 2                         NaN              NaN                      NaN
# 3                         NaN              NaN                      NaN
# 4                         NaN              NaN                      NaN
#
#   Booking Value  Ride Distance  Driver Ratings  Customer Rating  \
# 0           NaN            NaN             NaN              NaN
# 1         237.0           5.73             NaN              NaN
# 2         627.0          13.58             4.9              4.9
# 3         416.0          34.02             4.6              5.0
# 4         737.0          48.21             4.1              4.3
#
#    Payment Method
# 0             NaN
# 1             UPI
# 2      Debit Card
# 3             UPI
# 4             UPI
#
# [5 rows x 21 columns]

# %% [markdown]
# Convert Date and Time to DateTime...

# %%
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
df['Time'] = pd.to_datetime(df['Time'], format='%H:%M%S', errors= 'coerce').dt.time
display(df[['Date', 'Time']].head())
# Out:
#         Date Time
# 0 2024-03-23  NaT
# 1 2024-11-29  NaT
# 2 2024-08-23  NaT
# 3 2024-10-21  NaT
# 4 2024-09-16  NaT

# %% [markdown]
# Handle Missing Values..
#
# 1--- Fill numeric missing with median

# %%
numeric_cols = ['Avg VTAT', 'Avg CTAT', 'Booking Value', 'Ride Distance', 'Driver Ratings', 'Customer Rating']
for col in numeric_cols:
    df[col] = df[col].fillna(df[col].median())
display(df[numeric_cols].head())
# Out:
#    Avg VTAT  Avg CTAT  Booking Value  Ride Distance  Driver Ratings  \
# 0       8.3      28.8          414.0          23.72             4.3
# 1       4.9      14.0          237.0           5.73             4.3
# 2      13.4      25.8          627.0          13.58             4.9
# 3      13.1      28.5          416.0          34.02             4.6
# 4       5.3      19.6          737.0          48.21             4.1
#
#    Customer Rating
# 0              4.5
# 1              4.5
# 2              4.9
# 3              5.0
# 4              4.3

# %% [markdown]
# Fill Payment Method Missing with Unknown

# %%
df['Payment Method'] = df['Payment Method'].fillna('Unknown')
display(df['Payment Method'].head())
# Out:
# 0       Unknown
# 1           UPI
# 2    Debit Card
# 3           UPI
# 4           UPI
# Name: Payment Method, dtype: object

# %% [markdown]
# Fill Bookings status for missings if any ..

# %%
df['Booking Status'] = df['Booking Status'].fillna('Unknown ')
display(df['Booking Status'].value_counts())
# Out:
# Booking Status
# Completed                93000
# Cancelled by Driver      27000
# No Driver Found          10500
# Cancelled by Customer    10500
# Incomplete                9000
# Name: count, dtype: int64

# %% [markdown]
# Drop rows with completely missing Date or Bookings ID

# %%
print("Number of rows before dropping missing 'Date' or 'Booking ID':", len(df))
df = df.dropna(subset=['Date', 'Booking ID'])
print("Number of rows after dropping missing 'Date' or 'Booking ID':", len(df))
# Out:
# Number of rows before dropping missing 'Date' or 'Booking ID': 150000
# Number of rows after dropping missing 'Date' or 'Booking ID': 150000

# %% [markdown]
# Remove Duplicates..

# %%
print("Number of rows before dropping duplicates:", len(df))
df.drop_duplicates(inplace=True)
print("Number of rows after dropping duplicates:", len(df))
# Out:
# Number of rows before dropping duplicates: 150000
# Number of rows after dropping duplicates: 150000

# %% [markdown]
# Create Additonal Columns For Analysis..

# %%
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day
df['Day of Week'] = df['Date'].dt.day_name()
display(df.head())
# Out:
#         Date Time    Booking ID   Booking Status   Customer ID   Vehicle Type  \
# 0 2024-03-23  NaT  "CNR5884300"  No Driver Found  "CID1982111"          eBike
# 1 2024-11-29  NaT  "CNR1326809"       Incomplete  "CID4604802"       Go Sedan
# 2 2024-08-23  NaT  "CNR8494506"        Completed  "CID9202816"           Auto
# 3 2024-10-21  NaT  "CNR8906825"        Completed  "CID2610914"  Premier Sedan
# 4 2024-09-16  NaT  "CNR1950162"        Completed  "CID9933542"           Bike
#
#        Pickup Location      Drop Location  Avg VTAT  Avg CTAT  ...  \
# 0          Palam Vihar            Jhilmil       8.3      28.8  ...
# 1        Shastri Nagar  Gurgaon Sector 56       4.9      14.0  ...
# 2              Khandsa      Malviya Nagar      13.4      25.8  ...
# 3  Central Secretariat           Inderlok      13.1      28.5  ...
# 4     Ghitorni Village        Khan Market       5.3      19.6  ...
#
#    Incomplete Rides Incomplete Rides Reason  Booking Value Ride Distance  \
# 0               NaN                     NaN          414.0         23.72
# 1               1.0       Vehicle Breakdown          237.0          5.73
# 2               NaN                     NaN          627.0         13.58
# 3               NaN                     NaN          416.0         34.02
# 4               NaN                     NaN          737.0         48.21
#
#    Driver Ratings Customer Rating  Payment Method  Month  Day  Day of Week
# 0             4.3             4.5         Unknown      3   23     Saturday
# 1             4.3             4.5             UPI     11   29       Friday
# 2             4.9             4.9      Debit Card      8   23       Friday
# 3             4.6             5.0             UPI     10   21       Monday
# 4             4.1             4.3             UPI      9   16       Monday
#
# [5 rows x 24 columns]

# %% [markdown]
# Save Cleaned Data

# %%
df.to_csv("/content/ncr_ride_bookings_cleaned.csv", index=False)
print("Cleaning completed! Cleaned file saved as ncr_ride_bookings_cleaned.csv")
# Out:
# Cleaning completed! Cleaned file saved as ncr_ride_bookings_cleaned.csv

# %% [markdown]
# EDA (Exploratory Data Analysis Code)

# %% [markdown]
# 1-- Total Rides per Month..

# %%
df = pd.read_csv('/content/ncr_ride_bookings_cleaned.csv')
rides_by_month = df['Month'].value_counts().sort_index()
plt.figure(figsize=(8, 5))
rides_by_month.plot(kind='bar', color='skyblue')
plt.title('Total Rides per Month')
plt.xlabel('Month')
plt.ylabel('Number of Rides')
plt.show()

# %% [markdown]
# Revenue Trend

# %%
df = pd.read_csv('/content/ncr_ride_bookings_cleaned.csv')
plt.figure(figsize=(12, 6))
daily_revenue.plot(kind='line', color='green')
plt.title('Daily Revenue Trend')
plt.xlabel('Date')
plt.ylabel('Total Revenue (INR)')
plt.show()

# %% [markdown]
# Popular Vehicles Types

# %%
df = pd.read_csv('/content/ncr_ride_bookings_cleaned.csv')
vehicle_counts = df['Vehicle Type'].value_counts()
plt.figure(figsize=(8, 5))
vehicle_counts.plot(kind='bar', color='orange')
plt.title('Popular Vehicle Types')
plt.xlabel('Vehicle Type')
plt.ylabel('Number of bookings')
plt.show()

# %% [markdown]
# Payment Preferences

# %%
df = pd.read_csv('/content/ncr_ride_bookings_cleaned.csv')
payment_count = df['Payment Method'].value_counts()
plt.figure(figsize=(8, 5))
payment_count.plot(kind='bar', color='purple')
plt.title('Payment Method Preferences')
plt.xlabel('Payment method')
plt.ylabel('Number of bookings')
plt.show()
